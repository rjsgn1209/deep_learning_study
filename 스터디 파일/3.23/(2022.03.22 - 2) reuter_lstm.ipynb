# %%
import numpy as np
import pandas as p
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from tensorflow.keras.datasets import reuters
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, SimpleRNN, Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
(x_train, y_train), (x_test ,y_test) = reuters.load_data(num_words=1000, test_split=0.2)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2113536/2110848 [==============================] - 0s 0us/step
# 2121728/2110848 [==============================] - 0s 0us/step

# %%
print(x_train.shape, x_test.shape)
# Out:
# (8982,) (2246,)

# %%
print(y_train.shape, y_test.shape)
# Out:
# (8982,) (2246,)

# %%
x_train[:3]
# Out:
# array([list([1, 2, 2, 8, 43, 10, 447, 5, 25, 207, 270, 5, 2, 111, 16, 369, 186, 90, 67, 7, 89, 5, 19, 102, 6, 19, 124, 15, 90, 67, 84, 22, 482, 26, 7, 48, 4, 49, 8, 864, 39, 209, 154, 6, 151, 6, 83, 11, 15, 22, 155, 11, 15, 7, 48, 9, 2, 2, 504, 6, 258, 6, 272, 11, 15, 22, 134, 44, 11, 15, 16, 8, 197, 2, 90, 67, 52, 29, 209, 30, 32, 132, 6, 109, 15, 17, 12]),
#        list([1, 2, 699, 2, 2, 56, 2, 2, 9, 56, 2, 2, 81, 5, 2, 57, 366, 737, 132, 20, 2, 7, 2, 49, 2, 2, 2, 2, 699, 2, 8, 7, 10, 241, 16, 855, 129, 231, 783, 5, 4, 587, 2, 2, 2, 775, 7, 48, 34, 191, 44, 35, 2, 505, 17, 12]),
#        list([1, 53, 12, 284, 15, 14, 272, 26, 53, 959, 32, 818, 15, 14, 272, 26, 39, 684, 70, 11, 14, 12, 2, 18, 180, 183, 187, 70, 11, 14, 102, 32, 11, 29, 53, 44, 704, 15, 14, 19, 758, 15, 53, 959, 47, 2, 15, 14, 19, 132, 15, 39, 965, 32, 11, 14, 147, 72, 11, 180, 183, 187, 44, 11, 14, 102, 19, 11, 123, 186, 90, 67, 960, 4, 78, 13, 68, 467, 511, 110, 59, 89, 90, 67, 2, 55, 2, 92, 617, 80, 2, 46, 905, 220, 13, 4, 346, 48, 235, 629, 5, 211, 5, 2, 7, 2, 81, 5, 187, 11, 15, 9, 2, 201, 5, 47, 2, 18, 478, 2, 5, 2, 7, 232, 2, 71, 5, 160, 63, 11, 9, 2, 81, 5, 102, 59, 11, 17, 12])],
#       dtype=object)

# %%
y_train[:10]
# Out:
# array([ 3,  4,  3,  4,  4,  4,  4,  3,  3, 16], dtype=int64)

# %%
np.max(y_train) + 1     # 총 46개의 뉴스 카테고리
# Out:
# 46

# %%
lengths = [len(line) for line in x_train]    # 기사의 단어길이
lengths
# Out:
# [87,
#  56,
#  139,
#  224,
#  101,
#  116,
#  100,
#  100,
#  82,
#  106,
#  31,
#  59,
#  65,
#  316,
#  527,
#  76,
#  114,
#  17,
#  91,
#  77,
#  231,
#  108,
#  83,
#  29,
#  95,
#  110,
#  23,
#  373,
#  114,
#  354,
#  133,
#  222,
#  571,
#  155,
#  83,
#  208,
#  170,
#  269,
#  74,
#  19,
#  23,
#  78,
#  21,
#  377,
#  104,
#  299,
#  89,
#  56,
#  94,
#  139,
#  118,
#  36,
#  137,
#  107,
#  83,
#  66,
#  70,
#  112,
#  88,
#  51,
#  83,
#  123,
#  17,
#  185,
#  84,
#  52,
#  102,
#  73,
#  106,
#  486,
#  107,
#  82,
#  263,
#  172,
#  491,
#  190,
#  143,
#  62,
#  26,
#  88,
#  114,
#  38,
#  85,
#  112,
#  793,
#  104,
#  25,
#  21,
#  101,
#  28,
#  25,
#  81,
#  135,
#  73,
#  62,
#  18,
#  90,
#  266,
#  91,
#  64,
#  409,
#  92,
#  319,
#  166,
#  85,
#  200,
#  152,
#  474,
#  60,
#  58,
#  584,
#  71,
#  273,
#  51,
#  255,
#  28,
#  171,
#  143,
#  91,
#  46,
#  110,
#  77,
#  162,
#  24,
#  52,
#  175,
#  61,
#  95,
#  97,
#  259,
#  112,
#  73,
#  94,
#  17,
#  650,
#  23,
#  88,
#  309,
#  105,
#  89,
#  41,
#  314,
#  54,
#  374,
#  67,
#  160,
#  75,
#  207,
#  373,
#  84,
#  87,
#  74,
#  98,
#  136,
#  256,
#  95,
#  50,
#  108,
#  52,
#  100,
#  233,
#  86,
#  68,
#  47,
#  73,
#  158,
#  113,
#  23,
#  100,
#  80,
#  202,
#  104,
#  122,
#  101,
#  95,
#  118,
#  253,
#  192,
#  80,
#  183,
#  29,
#  604,
#  41,
#  103,
#  63,
#  147,
#  472,
#  58,
#  23,
#  37,
#  98,
#  73,
#  122,
#  812,
#  51,
#  179,
#  56,
#  60,
#  60,
#  25,
#  212,
#  34,
#  406,
#  122,
#  27,
#  86,
#  83,
#  43,
#  208,
#  26,
#  159,
#  65,
#  48,
#  335,
#  701,
#  314,
#  333,
#  68,
#  263,
#  124,
#  337,
#  180,
#  67,
#  81,
#  41,
#  92,
#  96,
#  185,
#  51,
#  75,
#  196,
#  54,
#  47,
#  48,
#  44,
#  166,
#  74,
#  111,
#  96,
#  167,
#  88,
#  100,
#  104,
#  36,
#  139,
#  35,
#  25,
#  17,
#  48,
#  88,
#  68,
#  36,
#  63,
#  115,
#  152,
#  82,
#  100,
#  181,
#  88,
#  109,
#  124,
#  234,
#  57,
#  199,
#  49,
#  131,
#  188,
#  192,
#  122,
#  290,
#  153,
#  297,
#  50,
#  71,
#  145,
#  185,
#  110,
#  93,
#  79,
#  116,
#  685,
#  28,
#  94,
#  260,
#  100,
#  88,
#  426,
#  24,
#  304,
#  28,
#  390,
#  224,
#  43,
#  48,
#  49,
#  17,
#  193,
#  158,
#  192,
#  169,
#  132,
#  132,
#  75,
#  94,
#  146,
#  41,
#  508,
#  61,
#  60,
#  121,
#  310,
#  232,
#  49,
#  49,
#  274,
#  297,
#  66,
#  142,
#  43,
#  17,
#  38,
#  245,
#  159,
#  57,
#  92,
#  149,
#  30,
#  67,
#  98,
#  16,
#  95,
#  481,
#  16,
#  16,
#  144,
#  178,
#  90,
#  56,
#  104,
#  303,
#  56,
#  222,
#  42,
#  222,
#  105,
#  87,
#  510,
#  30,
#  59,
#  81,
#  111,
#  82,
#  242,
#  26,
#  65,
#  67,
#  109,
#  83,
#  35,
#  100,
#  82,
#  106,
#  109,
#  58,
#  107,
#  65,
#  34,
#  41,
#  76,
#  57,
#  102,
#  748,
#  117,
#  23,
#  203,
#  78,
#  496,
#  139,
#  641,
#  75,
#  496,
#  524,
#  110,
#  17,
#  207,
#  34,
#  103,
#  96,
#  91,
#  170,
#  42,
#  100,
#  29,
#  807,
#  86,
#  58,
#  827,
#  116,
#  407,
#  174,
#  90,
#  100,
#  171,
#  59,
#  105,
#  255,
#  175,
#  171,
#  64,
#  17,
#  646,
#  103,
#  74,
#  226,
#  154,
#  18,
#  188,
#  96,
#  80,
#  719,
#  39,
#  70,
#  138,
#  392,
#  117,
#  70,
#  358,
#  188,
#  85,
#  83,
#  126,
#  93,
#  93,
#  17,
#  450,
#  34,
#  103,
#  200,
#  592,
#  35,
#  157,
#  82,
#  53,
#  67,
#  17,
#  27,
#  191,
#  222,
#  40,
#  31,
#  25,
#  133,
#  80,
#  226,
#  822,
#  16,
#  171,
#  204,
#  154,
#  81,
#  217,
#  82,
#  707,
#  100,
#  602,
#  48,
#  78,
#  44,
#  395,
#  44,
#  79,
#  53,
#  17,
#  55,
#  198,
#  70,
#  107,
#  161,
#  189,
#  79,
#  50,
#  82,
#  275,
#  64,
#  57,
#  41,
#  226,
#  68,
#  94,
#  118,
#  58,
#  75,
#  20,
#  173,
#  153,
#  199,
#  104,
#  52,
#  71,
#  107,
#  170,
#  79,
#  158,
#  202,
#  221,
#  200,
#  92,
#  188,
#  218,
#  51,
#  129,
#  75,
#  21,
#  17,
#  130,
#  134,
#  384,
#  61,
#  169,
#  25,
#  60,
#  293,
#  57,
#  105,
#  99,
#  112,
#  205,
#  593,
#  205,
#  239,
#  98,
#  94,
#  629,
#  397,
#  65,
#  220,
#  200,
#  132,
#  51,
#  269,
#  309,
#  204,
#  91,
#  54,
#  26,
#  163,
#  519,
#  91,
#  81,
#  208,
#  190,
#  73,
#  99,
#  96,
#  103,
#  75,
#  37,
#  45,
#  17,
#  874,
#  74,
#  107,
#  30,
#  28,
#  17,
#  30,
#  234,
#  16,
#  66,
#  233,
#  143,
#  373,
#  71,
#  92,
#  88,
#  311,
#  113,
#  674,
#  56,
#  40,
#  37,
#  107,
#  242,
#  171,
#  104,
#  258,
#  500,
#  75,
#  87,
#  90,
#  110,
#  126,
#  53,
#  17,
#  304,
#  23,
#  90,
#  57,
#  51,
#  88,
#  207,
#  100,
#  434,
#  73,
#  39,
#  17,
#  34,
#  199,
#  302,
#  136,
#  65,
#  119,
#  36,
#  310,
#  70,
#  136,
#  156,
#  229,
#  170,
#  136,
#  52,
#  84,
#  285,
#  158,
#  34,
#  16,
#  93,
#  98,
#  115,
#  197,
#  88,
#  175,
#  55,
#  304,
#  100,
#  74,
#  90,
#  109,
#  16,
#  66,
#  90,
#  88,
#  72,
#  102,
#  188,
#  140,
#  190,
#  72,
#  211,
#  103,
#  28,
#  85,
#  74,
#  55,
#  65,
#  90,
#  736,
#  66,
#  45,
#  133,
#  87,
#  216,
#  175,
#  62,
#  43,
#  576,
#  501,
#  66,
#  771,
#  703,
#  433,
#  73,
#  126,
#  95,
#  113,
#  90,
#  75,
#  91,
#  192,
#  120,
#  98,
#  328,
#  41,
#  54,
#  41,
#  43,
#  65,
#  248,
#  40,
#  98,
#  18,
#  149,
#  74,
#  49,
#  51,
#  93,
#  104,
#  99,
#  61,
#  62,
#  82,
#  81,
#  71,
#  83,
#  346,
#  610,
#  149,
#  130,
#  71,
#  199,
#  25,
#  1032,
#  87,
#  368,
#  143,
#  57,
#  59,
#  166,
#  217,
#  505,
#  32,
#  37,
#  70,
#  643,
#  24,
#  58,
#  49,
#  62,
#  287,
#  52,
#  693,
#  17,
#  722,
#  282,
#  192,
#  24,
#  58,
#  169,
#  89,
#  123,
#  564,
#  269,
#  109,
#  44,
#  173,
#  229,
#  184,
#  97,
#  583,
#  100,
#  41,
#  47,
#  58,
#  377,
#  68,
#  86,
#  17,
#  50,
#  177,
#  102,
#  600,
#  73,
#  192,
#  67,
#  79,
#  53,
#  78,
#  56,
#  187,
#  17,
#  17,
#  115,
#  94,
#  79,
#  67,
#  238,
#  85,
#  313,
#  200,
#  17,
#  95,
#  130,
#  143,
#  63,
#  244,
#  267,
#  18,
#  183,
#  178,
#  191,
#  78,
#  86,
#  40,
#  97,
#  232,
#  93,
#  83,
#  25,
#  90,
#  91,
#  36,
#  40,
#  150,
#  93,
#  204,
#  68,
#  78,
#  27,
#  316,
#  154,
#  383,
#  110,
#  80,
#  105,
#  43,
#  66,
#  105,
#  110,
#  60,
#  81,
#  160,
#  17,
#  56,
#  53,
#  149,
#  83,
#  177,
#  144,
#  63,
#  92,
#  244,
#  90,
#  39,
#  109,
#  455,
#  80,
#  17,
#  99,
#  189,
#  113,
#  74,
#  130,
#  64,
#  708,
#  105,
#  250,
#  68,
#  43,
#  33,
#  92,
#  90,
#  140,
#  746,
#  17,
#  91,
#  65,
#  146,
#  256,
#  485,
#  102,
#  17,
#  55,
#  51,
#  89,
#  58,
#  92,
#  93,
#  100,
#  225,
#  85,
#  113,
#  143,
#  86,
#  52,
#  113,
#  302,
#  101,
#  136,
#  296,
#  143,
#  88,
#  102,
#  171,
#  156,
#  251,
#  412,
#  143,
#  290,
#  21,
#  310,
#  63,
#  158,
#  198,
#  90,
#  77,
#  374,
#  17,
#  34,
#  186,
#  90,
#  50,
#  56,
#  90,
#  120,
#  130,
#  45,
#  96,
#  108,
#  185,
#  44,
#  187,
#  59,
#  17,
#  67,
#  269,
#  114,
#  234,
#  57,
#  94,
#  734,
#  102,
#  93,
#  240,
#  402,
#  108,
#  82,
#  17,
#  50,
#  65,
#  18,
#  77,
#  49,
#  65,
#  186,
#  153,
#  26,
#  113,
#  363,
#  49,
#  295,
#  81,
#  96,
#  137,
#  279,
#  308,
#  453,
#  29,
#  101,
#  138,
#  91,
#  253,
#  229,
#  84,
#  899,
#  126,
#  92,
#  192,
#  49,
#  184,
#  49,
#  19,
#  177,
#  241,
#  171,
#  22,
#  112,
#  472,
#  79,
#  49,
#  101,
#  41,
#  25,
#  69,
#  41,
#  142,
#  232,
#  52,
#  221,
#  87,
#  44,
#  35,
#  16,
#  306,
#  108,
#  41,
#  102,
#  629,
#  27,
#  254,
#  95,
#  65,
#  261,
#  25,
#  287,
#  416,
#  94,
#  63,
#  27,
#  133,
#  51,
#  ...]

# %%
plt.hist(lengths, bins = 100)
# Out:
# (array([9.680e+02, 1.324e+03, 1.435e+03, 1.482e+03, 7.290e+02, 3.690e+02,
#         4.230e+02, 4.010e+02, 2.960e+02, 1.920e+02, 1.730e+02, 1.680e+02,
#         1.660e+02, 8.200e+01, 8.800e+01, 7.600e+01, 6.300e+01, 5.300e+01,
#         5.300e+01, 6.500e+01, 3.700e+01, 3.900e+01, 3.300e+01, 2.600e+01,
#         3.500e+01, 2.900e+01, 3.000e+01, 1.300e+01, 2.300e+01, 2.400e+01,
#         1.400e+01, 1.400e+01, 1.200e+01, 1.300e+01, 7.000e+00, 8.000e+00,
#         5.000e+00, 5.000e+00, 1.000e+00, 0.000e+00, 2.000e+00, 0.000e+00,
#         0.000e+00, 2.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([  13.  ,   36.63,   60.26,   83.89,  107.52,  131.15,  154.78,
#          178.41,  202.04,  225.67,  249.3 ,  272.93,  296.56,  320.19,
#          343.82,  367.45,  391.08,  414.71,  438.34,  461.97,  485.6 ,
#          509.23,  532.86,  556.49,  580.12,  603.75,  627.38,  651.01,
#          674.64,  698.27,  721.9 ,  745.53,  769.16,  792.79,  816.42,
#          840.05,  863.68,  887.31,  910.94,  934.57,  958.2 ,  981.83,
#         1005.46, 1029.09, 1052.72, 1076.35, 1099.98, 1123.61, 1147.24,
#         1170.87, 1194.5 , 1218.13, 1241.76, 1265.39, 1289.02, 1312.65,
#         1336.28, 1359.91, 1383.54, 1407.17, 1430.8 , 1454.43, 1478.06,
#         1501.69, 1525.32, 1548.95, 1572.58, 1596.21, 1619.84, 1643.47,
#         1667.1 , 1690.73, 1714.36, 1737.99, 1761.62, 1785.25, 1808.88,
#         1832.51, 1856.14, 1879.77, 1903.4 , 1927.03, 1950.66, 1974.29,
#         1997.92, 2021.55, 2045.18, 2068.81, 2092.44, 2116.07, 2139.7 ,
#         2163.33, 2186.96, 2210.59, 2234.22, 2257.85, 2281.48, 2305.11,
#         2328.74, 2352.37, 2376.  ]),
#  <BarContainer object of 100 artists>)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
x_train_seq = pad_sequences(x_train, maxlen = 200)
x_test_seq = pad_sequences(x_test, maxlen = 200)

# %%
print(x_train_seq.shape, x_test_seq.shape)
# Out:
# (8982, 700) (2246, 700)

# %%
y_train_oh = to_categorical(y_train)
y_test_oh = to_categorical(y_test)

# %%
y_train_oh.shape
# Out:
# (8982, 46)

# %%
model = Sequential()
model.add(Embedding(1000, 30))
model.add(LSTM(100))
model.add(Dense(46, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 30)          30000
#
#  lstm (LSTM)                 (None, 100)               52400
#
#  dense (Dense)               (None, 46)                4646
#
# =================================================================
# Total params: 87,046
# Trainable params: 87,046
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy', metrics = ['accuracy'], optimizer = 'adam')

# %%
model.fit(x_train_seq, y_train_oh, epochs = 100, batch_size = 20, validation_data=(x_test_seq, y_test_oh))
# Out:
# Epoch 1/100
# 450/450 [==============================] - 28s 50ms/step - loss: 2.2830 - accuracy: 0.4269 - val_loss: 2.0294 - val_accuracy: 0.5036
# Epoch 2/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.9454 - accuracy: 0.5082 - val_loss: 1.8761 - val_accuracy: 0.5205
# Epoch 3/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.7655 - accuracy: 0.5495 - val_loss: 1.7023 - val_accuracy: 0.5721
# Epoch 4/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.7582 - accuracy: 0.5572 - val_loss: 1.9342 - val_accuracy: 0.5276
# Epoch 5/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.7456 - accuracy: 0.5522 - val_loss: 1.6789 - val_accuracy: 0.5766
# Epoch 6/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.6004 - accuracy: 0.5973 - val_loss: 1.5934 - val_accuracy: 0.6042
# Epoch 7/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.4993 - accuracy: 0.6183 - val_loss: 1.5237 - val_accuracy: 0.6278
# Epoch 8/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.4197 - accuracy: 0.6422 - val_loss: 1.5372 - val_accuracy: 0.6398
# Epoch 9/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.3403 - accuracy: 0.6690 - val_loss: 1.3874 - val_accuracy: 0.6612
# Epoch 10/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.3014 - accuracy: 0.6813 - val_loss: 1.4437 - val_accuracy: 0.6411
# Epoch 11/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.2266 - accuracy: 0.6905 - val_loss: 1.3143 - val_accuracy: 0.6723
# Epoch 12/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.1820 - accuracy: 0.7002 - val_loss: 1.2716 - val_accuracy: 0.6714
# Epoch 13/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.1399 - accuracy: 0.7086 - val_loss: 1.2752 - val_accuracy: 0.6634
# Epoch 14/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.0967 - accuracy: 0.7157 - val_loss: 1.2188 - val_accuracy: 0.6861
# Epoch 15/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.1325 - accuracy: 0.7181 - val_loss: 1.2254 - val_accuracy: 0.6883
# Epoch 16/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.0299 - accuracy: 0.7408 - val_loss: 1.1884 - val_accuracy: 0.6959
# Epoch 17/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.9835 - accuracy: 0.7483 - val_loss: 1.1840 - val_accuracy: 0.6906
# Epoch 18/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.2366 - accuracy: 0.6889 - val_loss: 1.2126 - val_accuracy: 0.7035
# Epoch 19/100
# 450/450 [==============================] - 22s 49ms/step - loss: 1.0158 - accuracy: 0.7410 - val_loss: 1.1487 - val_accuracy: 0.7146
# Epoch 20/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.9341 - accuracy: 0.7633 - val_loss: 1.1216 - val_accuracy: 0.7186
# Epoch 21/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.8922 - accuracy: 0.7776 - val_loss: 1.0942 - val_accuracy: 0.7293
# Epoch 22/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.8581 - accuracy: 0.7847 - val_loss: 1.0766 - val_accuracy: 0.7311
# Epoch 23/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.8302 - accuracy: 0.7925 - val_loss: 1.0815 - val_accuracy: 0.7315
# Epoch 24/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.8005 - accuracy: 0.7983 - val_loss: 1.0649 - val_accuracy: 0.7404
# Epoch 25/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.7839 - accuracy: 0.8039 - val_loss: 1.0744 - val_accuracy: 0.7360
# Epoch 26/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.7674 - accuracy: 0.8066 - val_loss: 1.0672 - val_accuracy: 0.7422
# Epoch 27/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.7218 - accuracy: 0.8201 - val_loss: 1.0878 - val_accuracy: 0.7400
# Epoch 28/100
# 450/450 [==============================] - 23s 51ms/step - loss: 0.7111 - accuracy: 0.8230 - val_loss: 1.0599 - val_accuracy: 0.7453
# Epoch 29/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.6759 - accuracy: 0.8321 - val_loss: 1.0608 - val_accuracy: 0.7427
# Epoch 30/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.6561 - accuracy: 0.8337 - val_loss: 1.0717 - val_accuracy: 0.7369
# Epoch 31/100
# 450/450 [==============================] - 23s 51ms/step - loss: 0.6272 - accuracy: 0.8440 - val_loss: 1.0872 - val_accuracy: 0.7502
# Epoch 32/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.6278 - accuracy: 0.8445 - val_loss: 1.0936 - val_accuracy: 0.7484
# Epoch 33/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.5949 - accuracy: 0.8534 - val_loss: 1.0942 - val_accuracy: 0.7462
# Epoch 34/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.5665 - accuracy: 0.8580 - val_loss: 1.0968 - val_accuracy: 0.7524
# Epoch 35/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.5324 - accuracy: 0.8635 - val_loss: 1.1215 - val_accuracy: 0.7386
# Epoch 36/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.5147 - accuracy: 0.8707 - val_loss: 1.1241 - val_accuracy: 0.7409
# Epoch 37/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.5056 - accuracy: 0.8735 - val_loss: 1.1646 - val_accuracy: 0.7458
# Epoch 38/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.4771 - accuracy: 0.8790 - val_loss: 1.1959 - val_accuracy: 0.7409
# Epoch 39/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.4759 - accuracy: 0.8822 - val_loss: 1.2219 - val_accuracy: 0.7244
# Epoch 40/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.4516 - accuracy: 0.8862 - val_loss: 1.2006 - val_accuracy: 0.7471
# Epoch 41/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.4197 - accuracy: 0.8966 - val_loss: 1.2103 - val_accuracy: 0.7382
# Epoch 42/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.4058 - accuracy: 0.8968 - val_loss: 1.2284 - val_accuracy: 0.7400
# Epoch 43/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.4013 - accuracy: 0.8970 - val_loss: 1.2451 - val_accuracy: 0.7476
# Epoch 44/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.3729 - accuracy: 0.9028 - val_loss: 1.2589 - val_accuracy: 0.7418
# Epoch 45/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.3557 - accuracy: 0.9059 - val_loss: 1.2789 - val_accuracy: 0.7449
# Epoch 46/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.3463 - accuracy: 0.9105 - val_loss: 1.2951 - val_accuracy: 0.7449
# Epoch 47/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.3239 - accuracy: 0.9165 - val_loss: 1.3404 - val_accuracy: 0.7435
# Epoch 48/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.3258 - accuracy: 0.9151 - val_loss: 1.3376 - val_accuracy: 0.7444
# Epoch 49/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.3015 - accuracy: 0.9212 - val_loss: 1.3767 - val_accuracy: 0.7435
# Epoch 50/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.2886 - accuracy: 0.9246 - val_loss: 1.4275 - val_accuracy: 0.7409
# Epoch 51/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.2714 - accuracy: 0.9286 - val_loss: 1.4194 - val_accuracy: 0.7484
# Epoch 52/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.2755 - accuracy: 0.9244 - val_loss: 1.4513 - val_accuracy: 0.7400
# Epoch 53/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.2440 - accuracy: 0.9333 - val_loss: 1.5095 - val_accuracy: 0.7373
# Epoch 54/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.2464 - accuracy: 0.9302 - val_loss: 1.4901 - val_accuracy: 0.7413
# Epoch 55/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.2386 - accuracy: 0.9325 - val_loss: 1.5050 - val_accuracy: 0.7404
# Epoch 56/100
# 450/450 [==============================] - 22s 48ms/step - loss: 0.2300 - accuracy: 0.9331 - val_loss: 1.5533 - val_accuracy: 0.7337
# Epoch 57/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.2222 - accuracy: 0.9372 - val_loss: 1.5720 - val_accuracy: 0.7435
# Epoch 58/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.2123 - accuracy: 0.9383 - val_loss: 1.5593 - val_accuracy: 0.7409
# Epoch 59/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.2039 - accuracy: 0.9428 - val_loss: 1.5795 - val_accuracy: 0.7453
# Epoch 60/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1887 - accuracy: 0.9451 - val_loss: 1.6157 - val_accuracy: 0.7355
# Epoch 61/100
# 450/450 [==============================] - 22s 48ms/step - loss: 0.1943 - accuracy: 0.9408 - val_loss: 1.6577 - val_accuracy: 0.7360
# Epoch 62/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.2001 - accuracy: 0.9392 - val_loss: 1.6336 - val_accuracy: 0.7342
# Epoch 63/100
# 450/450 [==============================] - 23s 51ms/step - loss: 0.1771 - accuracy: 0.9443 - val_loss: 1.6712 - val_accuracy: 0.7386
# Epoch 64/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1654 - accuracy: 0.9473 - val_loss: 1.7143 - val_accuracy: 0.7395
# Epoch 65/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1711 - accuracy: 0.9460 - val_loss: 1.7502 - val_accuracy: 0.7409
# Epoch 66/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1711 - accuracy: 0.9464 - val_loss: 1.7365 - val_accuracy: 0.7351
# Epoch 67/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1790 - accuracy: 0.9437 - val_loss: 1.7113 - val_accuracy: 0.7369
# Epoch 68/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1524 - accuracy: 0.9496 - val_loss: 1.7343 - val_accuracy: 0.7355
# Epoch 69/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1451 - accuracy: 0.9509 - val_loss: 1.7617 - val_accuracy: 0.7378
# Epoch 70/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1463 - accuracy: 0.9487 - val_loss: 1.7644 - val_accuracy: 0.7409
# Epoch 71/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1444 - accuracy: 0.9505 - val_loss: 1.7587 - val_accuracy: 0.7413
# Epoch 72/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1329 - accuracy: 0.9510 - val_loss: 1.8131 - val_accuracy: 0.7391
# Epoch 73/100
# 450/450 [==============================] - 22s 50ms/step - loss: 0.1345 - accuracy: 0.9508 - val_loss: 1.7985 - val_accuracy: 0.7391
# Epoch 74/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1405 - accuracy: 0.9505 - val_loss: 1.8571 - val_accuracy: 0.7324
# Epoch 75/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1413 - accuracy: 0.9495 - val_loss: 1.8367 - val_accuracy: 0.7364
# Epoch 76/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1571 - accuracy: 0.9479 - val_loss: 1.8025 - val_accuracy: 0.7311
# Epoch 77/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1312 - accuracy: 0.9515 - val_loss: 1.8918 - val_accuracy: 0.7333
# Epoch 78/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1223 - accuracy: 0.9529 - val_loss: 1.8681 - val_accuracy: 0.7427
# Epoch 79/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1191 - accuracy: 0.9529 - val_loss: 1.9122 - val_accuracy: 0.7382
# Epoch 80/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1112 - accuracy: 0.9540 - val_loss: 1.9137 - val_accuracy: 0.7333
# Epoch 81/100
# 450/450 [==============================] - 22s 50ms/step - loss: 0.1181 - accuracy: 0.9525 - val_loss: 1.9655 - val_accuracy: 0.7275
# Epoch 82/100
# 450/450 [==============================] - 22s 50ms/step - loss: 0.1299 - accuracy: 0.9491 - val_loss: 1.8905 - val_accuracy: 0.7306
# Epoch 83/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1188 - accuracy: 0.9521 - val_loss: 1.9431 - val_accuracy: 0.7329
# Epoch 84/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1151 - accuracy: 0.9516 - val_loss: 1.9479 - val_accuracy: 0.7311
# Epoch 85/100
# 450/450 [==============================] - 23s 52ms/step - loss: 0.1100 - accuracy: 0.9551 - val_loss: 1.9452 - val_accuracy: 0.7333
# Epoch 86/100
# 450/450 [==============================] - 23s 51ms/step - loss: 0.1076 - accuracy: 0.9521 - val_loss: 1.9761 - val_accuracy: 0.7324
# Epoch 87/100
# 450/450 [==============================] - 22s 50ms/step - loss: 0.1085 - accuracy: 0.9545 - val_loss: 2.0027 - val_accuracy: 0.7293
# Epoch 88/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1108 - accuracy: 0.9530 - val_loss: 1.9693 - val_accuracy: 0.7320
# Epoch 89/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1338 - accuracy: 0.9479 - val_loss: 1.9658 - val_accuracy: 0.7324
# Epoch 90/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1200 - accuracy: 0.9512 - val_loss: 1.9539 - val_accuracy: 0.7346
# Epoch 91/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1059 - accuracy: 0.9536 - val_loss: 1.9930 - val_accuracy: 0.7364
# Epoch 92/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.0969 - accuracy: 0.9556 - val_loss: 2.0128 - val_accuracy: 0.7373
# Epoch 93/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1211 - accuracy: 0.9508 - val_loss: 1.9957 - val_accuracy: 0.7284
# Epoch 94/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1080 - accuracy: 0.9507 - val_loss: 2.0269 - val_accuracy: 0.7355
# Epoch 95/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.0947 - accuracy: 0.9550 - val_loss: 2.0224 - val_accuracy: 0.7306
# Epoch 96/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.0956 - accuracy: 0.9551 - val_loss: 2.0237 - val_accuracy: 0.7302
# Epoch 97/100
# 450/450 [==============================] - 22s 50ms/step - loss: 0.0984 - accuracy: 0.9542 - val_loss: 2.0023 - val_accuracy: 0.7315
# Epoch 98/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.0948 - accuracy: 0.9536 - val_loss: 2.0616 - val_accuracy: 0.7360
# Epoch 99/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.1012 - accuracy: 0.9530 - val_loss: 2.0514 - val_accuracy: 0.7271
# Epoch 100/100
# 450/450 [==============================] - 22s 49ms/step - loss: 0.0961 - accuracy: 0.9540 - val_loss: 1.9849 - val_accuracy: 0.7293
